# %%
import pandas as pd
import os
import numpy as np

# %%
pwd = os.getcwd()
dataset = pd.read_csv(pwd + '\\out.csv')
dataset.columns
dataset.fillna('Sem Registro', inplace = True)

# %%
#np.unique(dataset['Categoria'])
np.unique(dataset['Bairro'])
# Out:
# array(['9 De Abril', 'Abelhas', 'Acude I', 'Aero Clube',
#        'Aero Clube Volta Redonda - Rj', 'Agua Limpa', 'Ano Bom',
#        'Aterado', 'Aterrado', 'Açude', 'Açude 2', 'Açude Ii', 'B Jesus',
#        'Bairro Santo Agostinho', 'Barreira Cravo', 'Bela Vista',
#        'Belmonte', 'Belo Horizonte', 'Boa Sorte', 'Boa Vista',
#        'Boa Vista I', 'Boa Vista Ii', 'Boa Vista Iii', 'Bom Jesus',
#        'Caieira', 'Cailândia', 'Cajueiro', 'Candelária', 'Casa De Pedra',
#        'Centro', 'Centro Bm', 'Cerâmica', 'Cidade Nova', 'Colina',
#        'Colônia Santo Antônio', 'Conforto', 'Coqueiros', 'Dom Bosco',
#        'Duzentos E Quarenta E Nove', 'Eldorado', 'Eucaliptal', 'Fátima',
#        'Getúlio Vargas', 'Ilha Parque', 'Jardim Amali', 'Jardim Amalia',
#        'Jardim Amalia 1', 'Jardim Amália', 'Jardim Amália 2',
#        'Jardim Belvedere', 'Jardim Boa Vista', 'Jardim Central',
#        'Jardim Cidade Do Aco', 'Jardim Cidade Do Aço', 'Jardim Europa',
# ...

# %%
dataset_pt = dataset.replace({True:'Sim', False:'Não'})
dataset_pt1 = dataset_pt.replace({'MARKET':'Mercado', 'RESTAURANT': 'Restaurante', 'PHARMACY':'Farmácia', 'BEVERAGE':'Bebidas', 'PET':'Pet Shop'})
dataset_final = dataset_pt1.replace({'9 DE ABRIL':'Nove de Abril', 'NOVE DE ABRIL':'Nove de Abril', '9 de Abril':'Nove de Abril', 'ACUDE I':'Açude 1', 'Acude I':'Açude 1', 'Açude':'Açude 1', 'AERO CLUBE':'Aero Clube', 'AGUA LIMPA':'Água Limpa', 'ANO BOM':'Ano Bom', 'ATERRADO':'Aterrado', 'Aterado':'Aterrado', 
'Açude Ii':'Açude 2', 'B JESUS':'Bom Jesus', 'BOM JESUS':'Bom Jesus', 'Bom Jesus ':'Bom Jesus', 'BELA VISTA':'Bela Vista', 'BELMONTE':'Belmonte', 'BELO HORIZONTE':'Belo Horizonte', 
'Boa Vista I':'Boa Vista 1', 'Boa Vista Ii':'Boa Vista 2', 'Boa Vista Iii':'Boa Vista 3', 'CENTRO':'Centro','centro':'Centro', 'CIDADE NOVA':'Cidade Nova', 'CONFORTO':'Conforto',
'COQUEIROS':'Coqueiros', 'Coqueiros ':'Coqueiros', 'EUCALIPTAL':'Eucaliptal', 'Ilha Parque':'Parque das Ilhas', 'PARQUE DAS ILHAS':'Parque das Ilhas', 'JARDIM AMALIA':'Jardim Amália', 'Jardim Amali':'Jardim Amália', 'Jardim Amalia':'Jardim Amália', 'Jardim Amalia 1':'Jardim Amália', 'Jardim amalia':'Jardim Amália', 
'JARDIM BELVEDERE':'Jardim Belvedere', 'JARDIM CIDADE DO ACO':'Jardim Cidade do Aço', 'Jardim Cidade do Aco':'Jardim Cidade do Aço', 'JARDIM NORMANDIA':'Jardim Normandia','Jardim NORMANDIA':'Jardim Normandia', 
'JARDIM PONTE ALTA':'Jardim Ponte Alta', 'JARDIM VILA RICA - TIRADENTES':'Jardim Vila Rica - Tiradentes', 'Jardim paraiba':'Jardim Paraíba', 'MANGUEIRA':'Mangueira', 'MINERLANDIA':'Minerlândia', 'Minerlandia':'Minerlândia', 'MONTE CASTELO':'Monte Castelo',
'NITEROI':'Niterói', 'Nossa Senhora das Gracas':'Nossa Senhora das Graças', 'PARAISO':'Paraíso', 'PARQUE DO CONTORNO':'Parque do Contorno', 'PINTO DA SERRA':'Pinto da Serra',
'Padre Josimo':'Padre Jósimo', 'Padre Josino':'Padre Jósimo', 'RETIRO':'Retiro', 'SANTA CECILIA':'Vila Santa Cecília', 'Santa Cecília':'Vila Santa Cecília', 'Santa Cecilia':'Vila Santa Cecília', 'VILA SANTA CECILIA':'Vila Santa Cecília', 'VL SANTA CECILIA':'Vila Santa Cecília', 'VILA SANTA CECÍLIA':'Vila Santa Cecília', 'Vila Santa Cecilia':'Vila Santa Cecília', 
'SANTA CRUZ':'Santa Cruz', 'Santa cruz':'Santa Cruz', 'santa Cruz':'Santa Cruz', 'Santa Cruz Ii':'Santa Cruz 2', 'SANTO AGOSTINHO':'Santo Agostinho', 'Santo agostinho':'Santo Agostinho', 'SAO CARLOS':'São Carlos', 'SAO CRISTOVAO':'São Cristóvão', 'SAO GERALDO':'São Geraldo', 'Sao Geraldo':'São Geraldo',
'SAO JOAO':'São João', 'Sao Joao':'São João', 'SAO LUCAS':'São Lucas', 'SAO LUIS':'São Luís', 'São Luis':'São Luís', 'SESSENTA':'Sessenta', 'SIDERLANDIA':'Siderlândia', 'Siderlandia':'Siderlândia', 'siderlandia':'Siderlândia', 'SIDEROPOLIS':'Siderópolis',
'TRES POÇOS':'Três Poços', 'VILA BRASILIA':'Vila Brasília', 'VILA MARIA':'Vila Maria', 'VILA MURY':'Vila Mury', 'VILA NOVA':'Vila Nova', 'VOLTA GRANDE':'Volta Grande', 'Volta Grande Ii':'Volta Grande 2',
'VOLTA GRANDE 3':'Volta Grande 3', 'Vila Rica Tiradentes':'Vila Rica', 'VOLDAC':'Voldac', 'voldac':'Voldac', 'ÁGua Comprida':'Água Comprida', 'ÁGua Limpa':'Água Limpa', 'VOLTA REDONDA':'Volta Redonda'})
dataset_final
# Out:
#                                       Loja    Categoria Sub Categoria  \
# 0                          Bebidas Express  Restaurante       Bebidas
# 1                        M&m´s São Geraldo  Restaurante       Lanches
# 2     Bob's - Drive Avenida Getúlio Vargas  Restaurante       Lanches
# 3                 Sider Lanches Lanchonete  Restaurante       Lanches
# 4                            Texas Lanches  Restaurante       Lanches
# ...                                    ...          ...           ...
# 1578                    Paiva Supermercado      Mercado       Mercado
# 1579   Droga Raia - Volta Redonda D - 2728     Farmácia       Mercado
# 1580   Drogarias Pacheco - Volta Redonda 3     Farmácia       Mercado
# 1581           Armazem Patinhas - Pet Shop     Pet Shop       Mercado
# 1582                        Rede Mundo Pet     Pet Shop       Mercado
#
#       Distância  Nota  Contagem de Votos Ifood Delivery Novo  \
# 0          2.90   5.0                  2            Não  Sim
# ...

# %%
dataset_final
# np.unique(dataset_final['Bairro'])
# Out:
#                                       Loja    Categoria Sub Categoria  \
# 0                          Bebidas Express  Restaurante       Bebidas
# 1                        M&m´s São Geraldo  Restaurante       Lanches
# 2     Bob's - Drive Avenida Getúlio Vargas  Restaurante       Lanches
# 3                 Sider Lanches Lanchonete  Restaurante       Lanches
# 4                            Texas Lanches  Restaurante       Lanches
# ...                                    ...          ...           ...
# 1578                    Paiva Supermercado      Mercado       Mercado
# 1579   Droga Raia - Volta Redonda D - 2728     Farmácia       Mercado
# 1580   Drogarias Pacheco - Volta Redonda 3     Farmácia       Mercado
# 1581           Armazem Patinhas - Pet Shop     Pet Shop       Mercado
# 1582                        Rede Mundo Pet     Pet Shop       Mercado
#
#       Distância  Nota  Contagem de Votos Ifood Delivery Novo  \
# 0          2.90   5.0                  2            Não  Sim
# ...

# %%
output = dataset_final.copy()

# %%
output.to_csv("Planilha Lojas.csv", encoding = 'utf-8-sig', index = False)
